# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\jyoti\ds-numpy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
students_names=["sanjay","Rahul","Karan","Wasim","Ramesh","Ajay","Sartaj","Priya"]
students_marks=[35,50,20,45,25,40,25,40]

# %%
import matplotlib.pyplot as plt

# %%
marks_perc = []
for x in students_marks:
	res = (x/50)*100
	marks_perc.append(res)

# %%
print(marks_perc)
# Out:
# [70.0, 100.0, 40.0, 90.0, 50.0, 80.0, 50.0, 80.0]

# %%
# line chart
def marks_line_chart():
  plt.plot(students_names,students_marks)
  plt.title("Students Marks Graph")
  plt.xlabel("Students Names")
  plt.ylabel("Students Marks")
  plt.show()

# %%
marks_line_chart()

# %%
def percentage_bar_chart():
  plt.bar(students_names,marks_perc)
  plt.title("Students' Percentage Graph")
  plt.xlabel("Student Names")
  plt.ylabel("Student Percentage")
  plt.show()

percentage_bar_chart()
